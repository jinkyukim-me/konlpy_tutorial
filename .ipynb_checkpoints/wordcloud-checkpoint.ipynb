# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
# 이미지 열기
im = Image.open('tomato.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=493x335 at 0x2868E670240>

# %%
im.size
# Out:
# (493, 335)

# %%
# 이미지 JPG로 저장
im.save('tomato2.jpg')

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %%
text = open('C:/dev/konlpy_tutorial/data/alice.txt').read()

# %%
alice_mask = np.array(Image.open('C:/dev/konlpy_tutorial/alice_mask.png'))

# %%
alice_mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
alice_mask.shape
# Out:
# (480, 640, 4)

# %%
stopwords = set(STOPWORDS)

# %%
stopwords.add("said")

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
# ...

# %%
import matplotlib.pyplot as plt
import platform

# %%
path = "c:/Windows/Fonts/malgun.ttf"

# %%
from matplotlib import font_manager, rc

# %%
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system.. sorry~~~~')

# %matplotlib inline

# %%
plt.figure(figsize=(8,8))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)
wc = wc.generate(text)
wc.words_
# Out:
# {'Alice': 1.0,
#  'little': 0.29916897506925205,
#  'one': 0.2631578947368421,
#  'know': 0.24930747922437674,
#  'went': 0.2299168975069252,
#  'thing': 0.22160664819944598,
#  'time': 0.21329639889196675,
#  'Queen': 0.21052631578947367,
#  'see': 0.18559556786703602,
#  'King': 0.1772853185595568,
#  'now': 0.16620498614958448,
#  'head': 0.16620498614958448,
#  'began': 0.16066481994459833,
#  'way': 0.15789473684210525,
#  'Hatter': 0.15789473684210525,
#  'Mock Turtle': 0.15512465373961218,
#  'say': 0.1523545706371191,
#  'Gryphon': 0.1523545706371191,
#  'well': 0.14958448753462603,
#  'think': 0.14681440443213298,
#  'quite': 0.1440443213296399,
#  'much': 0.14127423822714683,
#  'first': 0.14127423822714683,
#  'go': 0.13850415512465375,
#  'thought': 0.13573407202216067,
#  'come': 0.1329639889196676,
#  'never': 0.13019390581717452,
#  'voice': 0.12742382271468145,
#  'looked': 0.12465373961218837,
#  'got': 0.12465373961218837,
#  'must': 0.12188365650969529,
# ...

# %%
plt.figure(figsize=(100,100))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text1 = open('C:/dev/konlpy_tutorial/data/ratings_train.txt', encoding='UTF8').read()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)
wc = wc.generate(text1)
wc.words_
# Out:
# {'영화': 1.0,
#  '정말': 0.6901306240928883,
#  '진짜': 0.6199806482825351,
#  '너무': 0.5394291243347847,
#  '그냥': 0.3704644412191582,
#  'ㅋㅋ': 0.2838655055636188,
#  '그리고': 0.21649733913884858,
#  '영화는': 0.21504596032897919,
#  '이런': 0.21202225447508466,
#  '영화가': 0.19339622641509435,
#  '내가': 0.1929124334784712,
#  '완전': 0.18988872762457668,
#  '영화를': 0.1761006289308176,
#  '이거': 0.17537493952588293,
#  '드라마': 0.1741654571843251,
#  '이렇게': 0.1665457184325109,
#  '역시': 0.16545718432510886,
#  'ㅋㅋㅋ': 0.16461054668601838,
#  '이건': 0.16231253023705855,
#  'ㅠㅠ': 0.15953072085147557,
#  '이게': 0.14211417513304306,
#  '최고': 0.14138848572810836,
#  '평점': 0.13945331398161587,
#  '보고': 0.13376874697629415,
#  'ㅡㅡ': 0.13292210933720366,
#  '없다': 0.13098693759071117,
#  '스토리': 0.12203676826318335,
#  'ㅎㅎ': 0.12131107885824867,
#  '하지만': 0.1204644412191582,
#  '많이': 0.1113933236574746,
#  '솔직히': 0.10970004837929366,
#  '연기': 0.10933720367682633,
#  '별로': 0.102322206095791,
# ...

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
